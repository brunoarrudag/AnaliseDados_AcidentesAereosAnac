# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
acidentes_aereos = pd.read_csv('drive/MyDrive/Files/V_OCORRENCIA_AMPLA.csv', skiprows=1,sep=';')

# %%
acidentes_aereos.dtypes

# %%
#print(acidentes_aereos[['Data_da_Ocorrencia','Numero_da_Ficha', 'Classificacao_da_Ocorrencia']])

acidentes_aereos

# %%
acidentes_aereos.where(acidentes_aereos["Classificacao_da_Ocorrencia"] == "Acidente", inplace=True)

acidentes_aereos

# %%
contagem_valores = acidentes_aereos['Classificacao_da_Ocorrencia'].value_counts()
#Plotagem do gráfico de barras categorizar as quantidades de Acidentes e Incidentes.
contagem_valores.plot(kind='bar', figsize=(10, 6))
plt.title('Contagem de Acidentes Por categorias')
plt.xlabel('Valores')
plt.ylabel('Contagem')
plt.show()

# %%
acidentes_aereos['Data_da_Ocorrencia'] = pd.to_datetime(acidentes_aereos['Data_da_Ocorrencia'],
format='%Y-%m-%d')

#Extrair o ano da coluna Data da Ocorrencia:
acidentes_aereos['ano'] = acidentes_aereos['Data_da_Ocorrencia'].dt.year

# Agrupar os dados por ano e contar o número de acidentes por ano
acidentes_por_ano = acidentes_aereos.groupby('ano').size()

# Gerar um gráfico de linha mostrando a evolução dos acidentes ao longo dos anos
acidentes_por_ano.plot(kind='line', figsize=(10, 6))
plt.title('Evolução dos Acidentes Aéreos ao Longo dos Anos')
plt.xlabel('Ano')
plt.ylabel('Número de Acidentes')
plt.grid(True)
plt.show()
